# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/archive/REMS_Mars_Dataset.csv', 
                 encoding='utf-8', 
                 comment='#',
                 sep=',')

df.columns
# Out:
# Index(['earth_date_time', 'mars_date_time', 'sol_number',
#        'max_ground_temp(°C)', 'min_ground_temp(°C)', 'max_air_temp(°C)',
#        'min_air_temp(°C)', 'mean_pressure(Pa)', 'wind_speed(m/h)',
#        'humidity(%)', 'sunrise', 'sunset', 'UV_Radiation', 'weather'],
#       dtype='object')

# %%
df = df.drop(columns=['wind_speed(m/h)', 'humidity(%)'])
df.columns
# Out:
# Index(['earth_date_time', 'mars_date_time', 'sol_number',
#        'max_ground_temp(°C)', 'min_ground_temp(°C)', 'max_air_temp(°C)',
#        'min_air_temp(°C)', 'mean_pressure(Pa)', 'sunrise', 'sunset',
#        'UV_Radiation', 'weather'],
#       dtype='object')

# %%
df.head(10)
# Out:
#          earth_date_time           mars_date_time sol_number  \
# 0  Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°   Sol 3368
# 1  Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°   Sol 3367
# 2  Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°   Sol 3366
# 3  Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°   Sol 3365
# 4  Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°   Sol 3364
# 5  Earth, 2022-01-21 UTC  Mars, Month 6 - LS 161°   Sol 3363
# 6  Earth, 2022-01-20 UTC  Mars, Month 6 - LS 160°   Sol 3362
# 7  Earth, 2022-01-19 UTC  Mars, Month 6 - LS 160°   Sol 3361
# 8  Earth, 2022-01-18 UTC  Mars, Month 6 - LS 159°   Sol 3360
# 9  Earth, 2022-01-17 UTC  Mars, Month 6 - LS 158°   Sol 3359
#
#   max_ground_temp(°C) min_ground_temp(°C) max_air_temp(°C) min_air_temp(°C)  \
# 0                  -3                 -71               10              -84
# 1                  -3                 -72               10              -87
# ...

# %%
df.iloc[::-1]
# Out:
#             earth_date_time           mars_date_time sol_number  \
# 3196  Earth, 2012-08-07 UTC  Mars, Month 6 - LS 150°      Sol 1
# 3195  Earth, 2012-08-15 UTC  Mars, Month 6 - LS 155°      Sol 9
# 3194  Earth, 2012-08-16 UTC  Mars, Month 6 - LS 155°     Sol 10
# 3193  Earth, 2012-08-17 UTC  Mars, Month 6 - LS 156°     Sol 11
# 3192  Earth, 2012-08-18 UTC  Mars, Month 6 - LS 156°     Sol 12
# ...                     ...                      ...        ...
# 4     Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°   Sol 3364
# 3     Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°   Sol 3365
# 2     Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°   Sol 3366
# 1     Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°   Sol 3367
# 0     Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°   Sol 3368
#
#       max_ground_temp(°C)  min_ground_temp(°C)     max_air_temp(°C)  \
# 3196  Value not available  Value not available  Value not available
# ...

# %%
df = df.drop('weather', 1)
df['UV_Radiation'].unique()
# Out:
# array(['moderate', 'low', 'high', 'very_high', nan], dtype=object)

# %%
df = df.replace('Value not available', None)
df
# Out:
#             earth_date_time           mars_date_time sol_number  \
# 0     Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°   Sol 3368
# 1     Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°   Sol 3367
# 2     Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°   Sol 3366
# 3     Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°   Sol 3365
# 4     Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°   Sol 3364
# ...                     ...                      ...        ...
# 3192  Earth, 2012-08-18 UTC  Mars, Month 6 - LS 156°     Sol 12
# 3193  Earth, 2012-08-17 UTC  Mars, Month 6 - LS 156°     Sol 11
# 3194  Earth, 2012-08-16 UTC  Mars, Month 6 - LS 155°     Sol 10
# 3195  Earth, 2012-08-15 UTC  Mars, Month 6 - LS 155°      Sol 9
# 3196  Earth, 2012-08-07 UTC  Mars, Month 6 - LS 150°      Sol 1
#
#      max_ground_temp(°C) min_ground_temp(°C) max_air_temp(°C)  \
# 0                     -3                 -71               10
# 1                     -3                 -72               10
# ...

# %%
df['UV_Radiation'] = df['UV_Radiation'].replace(['low', 'moderate', 'high', 'very_high'], [0, 1, 2, 3])

# %%
df.head(10)
# Out:
#          earth_date_time           mars_date_time sol_number  \
# 0  Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°   Sol 3368
# 1  Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°   Sol 3367
# 2  Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°   Sol 3366
# 3  Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°   Sol 3365
# 4  Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°   Sol 3364
# 5  Earth, 2022-01-21 UTC  Mars, Month 6 - LS 161°   Sol 3363
# 6  Earth, 2022-01-20 UTC  Mars, Month 6 - LS 160°   Sol 3362
# 7  Earth, 2022-01-19 UTC  Mars, Month 6 - LS 160°   Sol 3361
# 8  Earth, 2022-01-18 UTC  Mars, Month 6 - LS 159°   Sol 3360
# 9  Earth, 2022-01-17 UTC  Mars, Month 6 - LS 158°   Sol 3359
#
#   max_ground_temp(°C) min_ground_temp(°C) max_air_temp(°C) min_air_temp(°C)  \
# 0                  -3                 -71               10              -84
# 1                  -3                 -72               10              -87
# ...

# %%
df['sol_number'] = df['sol_number'].str.extract('(\d+)').astype(int)

# %%
df.head(5)
# Out:
#          earth_date_time           mars_date_time  sol_number  \
# 0  Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°        3368
# 1  Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°        3367
# 2  Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°        3366
# 3  Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°        3365
# 4  Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°        3364
#
#   max_ground_temp(°C) min_ground_temp(°C) max_air_temp(°C) min_air_temp(°C)  \
# 0                  -3                 -71               10              -84
# 1                  -3                 -72               10              -87
# 2                  -4                 -70                8              -81
# 3                  -6                 -70                9              -91
# 4                  -7                 -71                8              -92
#
#   mean_pressure(Pa) sunrise sunset  UV_Radiation
# 0               707   05:25  17:20           1.0
# ...

# %%
pathdf = pd.read_csv('data/path.csv', 
                 encoding='utf-8', 
                 comment='#',
                 sep=',')

pathdf.columns
# Out:
# Index(['latitude', 'longitude', 'altitude', 'geometry', 'RMC', 'site', 'drive',
#        'sol', 'easting', 'northing', 'elev_geoid', 'lon', 'lat', 'roll',
#        'pitch', 'yaw', 'yaw_rad', 'tilt', 'dist_m', 'dist_total_m', 'dist_km',
#        'dist_mi', 'drive_type'],
#       dtype='object')

# %%
pathdf.head(5)
# Out:
#    latitude   longitude  altitude geometry    RMC  site  drive  sol  \
# 0 -4.589467  137.441633 -4500.971    Point    2_0     2      0    3
# 1 -4.589465  137.441734 -4501.120    Point   3_78     3     78   16
# 2 -4.589401  137.441686 -4501.386    Point  3_100     3    100   21
# 3 -4.589403  137.441893 -4502.364    Point  3_260     3    260   22
# 4 -4.589447  137.442181 -4502.611    Point  3_372     3    372   24
#
#        easting    northing  ...  roll  pitch     yaw  yaw_rad  tilt  dist_m  \
# 0  8146811.223 -272039.268  ... -2.42  -3.62  111.52  1.94637  4.35    0.00
# 1  8146817.210 -272039.150  ... -1.33   5.41 -132.02 -2.30426  5.57    7.01
# 2  8146814.363 -272035.346  ... -2.91   4.66 -164.69 -2.87437  5.49    4.90
# 3  8146826.607 -272035.482  ... -1.28  -4.29   64.62  1.12778  4.48   15.14
# 4  8146843.725 -272038.080  ... -1.37  -1.65  116.50  2.03331  2.14   21.51
#
#    dist_total_m  dist_km  dist_mi  drive_type
# 0          0.00     0.00     0.00       final
# ...

# %%
pathdf = pathdf.drop('geometry', 1)
pathdf = pathdf.drop('drive_type', 1)

# %%
pathdf = pathdf.drop('dist_mi', 1)

# %%
pathdf = pathdf.drop('lat', 1)
pathdf = pathdf.drop('lon', 1)

# %%
pathdf = pathdf.drop('elev_geoid', 1)

# %%
pathdf.head(5)
# Out:
#    latitude   longitude  altitude    RMC  site  drive  sol      easting  \
# 0 -4.589467  137.441633 -4500.971    2_0     2      0    3  8146811.223
# 1 -4.589465  137.441734 -4501.120   3_78     3     78   16  8146817.210
# 2 -4.589401  137.441686 -4501.386  3_100     3    100   21  8146814.363
# 3 -4.589403  137.441893 -4502.364  3_260     3    260   22  8146826.607
# 4 -4.589447  137.442181 -4502.611  3_372     3    372   24  8146843.725
#
#      northing  roll  pitch     yaw  yaw_rad  tilt  dist_m  dist_total_m  \
# 0 -272039.268 -2.42  -3.62  111.52  1.94637  4.35    0.00          0.00
# 1 -272039.150 -1.33   5.41 -132.02 -2.30426  5.57    7.01          7.01
# 2 -272035.346 -2.91   4.66 -164.69 -2.87437  5.49    4.90         11.91
# 3 -272035.482 -1.28  -4.29   64.62  1.12778  4.48   15.14         27.04
# 4 -272038.080 -1.37  -1.65  116.50  2.03331  2.14   21.51         48.55
#
#    dist_km
# 0     0.00
# 1     0.01
# 2     0.01
# 3     0.03
# 4     0.05

# %%
df.head(5)
# Out:
#          earth_date_time           mars_date_time  sol_number  \
# 0  Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°        3368
# 1  Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°        3367
# 2  Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°        3366
# 3  Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°        3365
# 4  Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°        3364
#
#   max_ground_temp(°C) min_ground_temp(°C) max_air_temp(°C) min_air_temp(°C)  \
# 0                  -3                 -71               10              -84
# 1                  -3                 -72               10              -87
# 2                  -4                 -70                8              -81
# 3                  -6                 -70                9              -91
# 4                  -7                 -71                8              -92
#
#   mean_pressure(Pa) sunrise sunset  UV_Radiation
# 0               707   05:25  17:20           1.0
# ...

# %%
pathdf.tail(5)
# Out:
#      latitude   longitude  altitude      RMC  site  drive   sol      easting  \
# 942 -4.753931  137.395729  -3924.82  95_1670    95   1670  3483  8144090.291
# 943 -4.754572  137.395851  -3920.18  95_2054    95   2054  3485  8144097.526
# 944 -4.754641  137.396254  -3919.50  95_2388    95   2388  3489  8144121.422
# 945 -4.754955  137.396391  -3916.30  95_2652    95   2652  3492  8144129.509
# 946 -4.755487  137.396500  -3912.76  95_2934    95   2934  3495  8144135.972
#
#        northing   roll  pitch     yaw  yaw_rad   tilt  dist_m  dist_total_m  \
# 942 -281787.810   0.39  11.25 -179.94 -3.14060  11.25   25.21      28275.25
# 943 -281825.831   0.71  18.20 -157.52 -2.74927  18.21   46.62      28321.86
# 944 -281829.901  17.26  17.37 -179.08 -3.12558  24.30   35.82      28357.68
# 945 -281848.510   3.38   9.32 -138.95 -2.42514   9.91   25.63      28383.31
# 946 -281880.055   5.17  15.13  162.53  2.83672  15.97   36.01      28419.32
#
#      dist_km
# 942    27.98
# 943    28.03
# ...

# %%
plt.scatter(pathdf['sol'], pathdf['altitude'])

# %%
df['max_air_temp(°C)'].unique()
# Out:
# array(['10', '8', '9', '5', '3', '4', '2', '0', '-1', '-7', '-3', '7',
#        '1', '6', '-5', '-6', '-8', '-13', '-14', '-12', '-15', '-60',
#        '-34', '-16', '-17', '-18', '-21', '-19', '-10', '-9', '-11', '-4',
#        '12', '11', '14', '15', '16', '-46', '17', '13', '-45', '22', '18',
#        '21', '19', '-2', '-24', '-61', '20', '24'], dtype=object)

# %%
df['sol_number']
# Out:
# 0       3368
# 1       3367
# 2       3366
# 3       3365
# 4       3364
#         ...
# 3192      12
# 3193      11
# 3194      10
# 3195       9
# 3196       1
# Name: sol_number, Length: 3197, dtype: int64

# %%
import seaborn as sns

df['UV_type'] = pd.cut(df['UV_Radiation'], 4)

df['max_air_temp(°C)'] = df['max_air_temp(°C)'].astype(float)
df['min_air_temp(°C)'] = df['min_air_temp(°C)'].astype(float)
df['max_ground_temp(°C)'] = df['max_ground_temp(°C)'].astype(float)
df['min_ground_temp(°C)'] = df['min_ground_temp(°C)'].astype(float)
df['mean_pressure(Pa)'] = df['mean_pressure(Pa)'].astype(float)
df['UV_Radiation'] = df['UV_Radiation'].astype(float)

sns.pairplot(df, vars=['sol_number', 'mean_pressure(Pa)', 'max_air_temp(°C)'], hue='UV_Radiation')

# %%
print(len(df['sol_number']), "and", len(pathdf['sol']))
# Out:
# 3197 and 947

# %%
print(len(pathdf['sol'].unique()), "and", len(df['sol_number'].unique()))
# Out:
# 947 and 3197

# %%
df['sol_number'][0]
# Out:
# 3368

# %%
counter = 0
for i in range(3197):
    for j in range(947):
        if df['sol_number'][i] == pathdf['sol'][j]:
            counter += 1
counter
# Out:
# 889

# %%
df = df.drop('UV_type', 1)

# %%
df.head(20)
# Out:
#           earth_date_time           mars_date_time  sol_number  \
# 0   Earth, 2022-01-26 UTC  Mars, Month 6 - LS 163°        3368
# 1   Earth, 2022-01-25 UTC  Mars, Month 6 - LS 163°        3367
# 2   Earth, 2022-01-24 UTC  Mars, Month 6 - LS 162°        3366
# 3   Earth, 2022-01-23 UTC  Mars, Month 6 - LS 162°        3365
# 4   Earth, 2022-01-22 UTC  Mars, Month 6 - LS 161°        3364
# 5   Earth, 2022-01-21 UTC  Mars, Month 6 - LS 161°        3363
# 6   Earth, 2022-01-20 UTC  Mars, Month 6 - LS 160°        3362
# 7   Earth, 2022-01-19 UTC  Mars, Month 6 - LS 160°        3361
# 8   Earth, 2022-01-18 UTC  Mars, Month 6 - LS 159°        3360
# 9   Earth, 2022-01-17 UTC  Mars, Month 6 - LS 158°        3359
# 10  Earth, 2022-01-16 UTC  Mars, Month 6 - LS 158°        3358
# 11  Earth, 2022-01-15 UTC  Mars, Month 6 - LS 157°        3357
# 12  Earth, 2022-01-14 UTC  Mars, Month 6 - LS 157°        3356
# 13  Earth, 2022-01-13 UTC  Mars, Month 6 - LS 156°        3355
# ...

# %%
counter = np.array(0)
for i in range(1, len(df)):
    if df['sol_number'][i-1] - df['sol_number'][i] > 1:
        counter = np.append(counter, i)
counter = counter[1::]
counter
# Out:
# array([  14,   23,   49,   81,   96,  165,  219,  318,  375,  525,  530,
#         597,  629,  988,  994, 1051, 1052, 1095, 1106, 1494, 1588, 1881,
#        1979, 2240, 2267, 2309, 2325, 2383, 2771, 2788, 2792, 2872, 2964,
#        3005, 3006, 3012, 3196])

# %%
diff = np.array(0)
for i in range(len(counter)):
    diff = np.append(diff, df['sol_number'][counter[i]-1]-df['sol_number'][counter[i]])
diff = diff[1::]
diff
# Out:
# array([ 2, 13,  2,  2,  5,  2,  7,  2,  2,  2,  3,  3,  2,  9, 14,  2,  3,
#         2, 30,  2,  2, 10,  3,  2,  2,  3,  2,  8,  7,  5, 10,  7,  5,  7,
#        15,  3,  8])

# %%
pathdf.head(20)
# Out:
#     latitude   longitude  altitude     RMC  site  drive  sol      easting  \
# 0  -4.589467  137.441633 -4500.971     2_0     2      0    3  8146811.223
# 1  -4.589465  137.441734 -4501.120    3_78     3     78   16  8146817.210
# 2  -4.589401  137.441686 -4501.386   3_100     3    100   21  8146814.363
# 3  -4.589403  137.441893 -4502.364   3_260     3    260   22  8146826.607
# 4  -4.589447  137.442181 -4502.611   3_372     3    372   24  8146843.725
# 5  -4.589749  137.442476 -4503.026   3_530     3    530   26  8146861.191
# 6  -4.590121  137.442894 -4503.559     4_0     4      0   29  8146885.959
# 7  -4.590243  137.443302 -4504.605   4_404     4    404   38  8146910.129
# 8  -4.590318  137.443663 -4504.758   4_468     4    468   39  8146931.566
# 9  -4.590036  137.444178 -4504.468   4_916     4    916   40  8146962.057
# 10 -4.589847  137.444581 -4504.953  4_1238     4   1238   41  8146985.961
# 11 -4.590042  137.445051 -4507.215  4_1632     4   1632   42  8147013.818
# ...

# %%
counterpath = np.array(0)
for i in range(1, len(pathdf)):
    if pathdf['sol'][i] - pathdf['sol'][i-1] > 1:
        counterpath = np.append(counterpath, i)
counterpath = counterpath[1::]

# %%
diffpath = np.array(0)
for i in range(len(counterpath)):
    diffpath = np.append(diffpath, pathdf['sol'][counterpath[i]]-pathdf['sol'][counterpath[i]-1])
diffpath = diffpath[1::]
diffpath
# Out:
# array([ 13,   5,   2,   2,   3,   9,   2,   3,   2,   2,   2,  41,   2,
#          9,   9,   2,   3,   3,  14,   4,   7,   3,   2, 106,   2,  21,
#          2,   2,   2,   5,   4,   4,   7,   3,   2,   2,   2,   2,   2,
#          2,   2,   2,   2,   3,   2,   2,   3,   2,   2,   4,   2,   2,
#          4,   2,   3,   2,   2,   4,   6,   2,   3,   2,   4,   2,   3,
#          2,   2,   3,   2,   2,   3,  13,  10,   5,   2,   2,   3,  11,
#          2,   4,  10,   2,   2,   3,   2,   2,   3,   3,   2,   4,   2,
#          3,   2,   2,   3,   2,   4,   2,   3,   2,   7,   5,   4,   2,
#          2,   6,   3,   3,  21,   3,   4,   2,   2,   3,   2,   4,   3,
#          3,   2,   2,   4,   2,   3,   3,   6,   2,   2,   2,   3,   2,
#         10,   2,   2,   2,   3,   3,   2,   3,   2,  27,   5,   2,   3,
#          2,   2,   3,   2,   4,   4,   5,   5,   9,   9,   2,  25,   2,
#         32,   5,   2,  20,   2,  14,   4,   5,   4,   2,   2,   3,   4,
# ...

# %%
pathdf['sol']
# Out:
# 0         3
# 1        16
# 2        21
# 3        22
# 4        24
#        ...
# 942    3483
# 943    3485
# 944    3489
# 945    3492
# 946    3495
# Name: sol, Length: 947, dtype: int64

# %%
df['sol_number']
# Out:
# 0       3368
# 1       3367
# 2       3366
# 3       3365
# 4       3364
#         ...
# 3192      12
# 3193      11
# 3194      10
# 3195       9
# 3196       1
# Name: sol_number, Length: 3197, dtype: int64

# %%
pathdf = pathdf.drop('dist_km', 1)

# %%
pathdf.head(5)
# Out:
#    latitude   longitude  altitude    RMC  site  drive  sol      easting  \
# 0 -4.589467  137.441633 -4500.971    2_0     2      0    3  8146811.223
# 1 -4.589465  137.441734 -4501.120   3_78     3     78   16  8146817.210
# 2 -4.589401  137.441686 -4501.386  3_100     3    100   21  8146814.363
# 3 -4.589403  137.441893 -4502.364  3_260     3    260   22  8146826.607
# 4 -4.589447  137.442181 -4502.611  3_372     3    372   24  8146843.725
#
#      northing  roll  pitch     yaw  yaw_rad  tilt  dist_m  dist_total_m
# 0 -272039.268 -2.42  -3.62  111.52  1.94637  4.35    0.00          0.00
# 1 -272039.150 -1.33   5.41 -132.02 -2.30426  5.57    7.01          7.01
# 2 -272035.346 -2.91   4.66 -164.69 -2.87437  5.49    4.90         11.91
# 3 -272035.482 -1.28  -4.29   64.62  1.12778  4.48   15.14         27.04
# 4 -272038.080 -1.37  -1.65  116.50  2.03331  2.14   21.51         48.55

# %%
pathdf = pathdf.drop('dist_total_m', 1)

# %%
pathdf = pathdf.drop('yaw_rad', 1)
pathdf = pathdf.drop('drive', 1)
pathdf = pathdf.drop('RMC', 1)
pathdf = pathdf.drop('site', 1)
pathdf = pathdf.drop(['easting', 'northing'], 1)
pathdf = pathdf.drop('dist_m', 1)

# %%
pathdf.head(5)
# Out:
#    latitude   longitude  altitude  sol  roll  pitch     yaw  tilt
# 0 -4.589467  137.441633 -4500.971    3 -2.42  -3.62  111.52  4.35
# 1 -4.589465  137.441734 -4501.120   16 -1.33   5.41 -132.02  5.57
# 2 -4.589401  137.441686 -4501.386   21 -2.91   4.66 -164.69  5.49
# 3 -4.589403  137.441893 -4502.364   22 -1.28  -4.29   64.62  4.48
# 4 -4.589447  137.442181 -4502.611   24 -1.37  -1.65  116.50  2.14

# %%
sols = np.asarray(pathdf['sol'])

# %%
df = df.drop(['sunrise', 'sunset'], 1)

# %%
df = df.drop(['earth_date_time', 'mars_date_time'], 1)

# %%
df.head(5)
# Out:
#    sol_number  max_ground_temp(°C)  min_ground_temp(°C)  max_air_temp(°C)  \
# 0        3368                 -3.0                -71.0              10.0
# 1        3367                 -3.0                -72.0              10.0
# 2        3366                 -4.0                -70.0               8.0
# 3        3365                 -6.0                -70.0               9.0
# 4        3364                 -7.0                -71.0               8.0
#
#    min_air_temp(°C)  mean_pressure(Pa)  UV_Radiation
# 0             -84.0              707.0           1.0
# 1             -87.0              707.0           1.0
# 2             -81.0              708.0           1.0
# 3             -91.0              707.0           1.0
# 4             -92.0              708.0           1.0

# %%
pathdf.head(5)
# Out:
#    latitude   longitude  altitude  sol  roll  pitch     yaw  tilt
# 0 -4.589467  137.441633 -4500.971    3 -2.42  -3.62  111.52  4.35
# 1 -4.589465  137.441734 -4501.120   16 -1.33   5.41 -132.02  5.57
# 2 -4.589401  137.441686 -4501.386   21 -2.91   4.66 -164.69  5.49
# 3 -4.589403  137.441893 -4502.364   22 -1.28  -4.29   64.62  4.48
# 4 -4.589447  137.442181 -4502.611   24 -1.37  -1.65  116.50  2.14

# %%
print(np.max(df['sol_number']))
pathdf['sol'][900]
b = np.arange(901, 947, 1)
pathdf = pathdf.drop(b, 0)
# Out:
# 3368

# %%
pathdf
# Out:
#      latitude   longitude  altitude   sol   roll  pitch     yaw   tilt
# 0   -4.589467  137.441633 -4500.971     3  -2.42  -3.62  111.52   4.35
# 1   -4.589465  137.441734 -4501.120    16  -1.33   5.41 -132.02   5.57
# 2   -4.589401  137.441686 -4501.386    21  -2.91   4.66 -164.69   5.49
# 3   -4.589403  137.441893 -4502.364    22  -1.28  -4.29   64.62   4.48
# 4   -4.589447  137.442181 -4502.611    24  -1.37  -1.65  116.50   2.14
# ..        ...         ...       ...   ...    ...    ...     ...    ...
# 896 -4.751423  137.393862 -3951.990  3359   5.95  11.79 -164.28  13.18
# 897 -4.751420  137.393863 -3951.970  3361   6.11  11.95 -164.25  13.40
# 898 -4.751227  137.393711 -3954.620  3363  10.32  10.76 -131.63  14.86
# 899 -4.751249  137.393684 -3954.120  3365   8.82  15.94 -133.34  18.16
# 900 -4.751245  137.393684 -3954.100  3367  11.37  17.01 -129.42  20.37
#
# [901 rows x 8 columns]

# %%
rover_sols = np.flip(np.asarray(df['sol_number']))
path_sols = np.asarray(pathdf['sol'])
lat = np.zeros(len(rover_sols))
lon = np.zeros(len(rover_sols))
alt = np.zeros(len(rover_sols))
roll = np.zeros(len(rover_sols))
pitch = np.zeros(len(rover_sols))
yaw = np.zeros(len(rover_sols))
tilt = np.zeros(len(rover_sols))

# %%
count = 0
path_count = 0
while count < len(rover_sols)-1:
    if rover_sols[count] <= path_sols[path_count] and rover_sols[count+1] > path_sols[path_count]:
        lat[count] = pathdf['latitude'][path_count]
        lat[count+1] = pathdf['latitude'][path_count]
        lon[count] = pathdf['longitude'][path_count]
        lon[count+1] = pathdf['longitude'][path_count]
        alt[count] = pathdf['altitude'][path_count]
        alt[count+1] = pathdf['altitude'][path_count]
        roll[count] = pathdf['roll'][path_count]
        roll[count+1] = pathdf['roll'][path_count]
        pitch[count] = pathdf['pitch'][path_count]
        pitch[count+1] = pathdf['pitch'][path_count]
        yaw[count] = pathdf['yaw'][path_count]
        yaw[count+1] = pathdf['yaw'][path_count]
        tilt[count] = pathdf['tilt'][path_count]
        tilt[count+1] = pathdf['tilt'][path_count]
        path_count += 1
        count += 1
    else:
        lat[count+1] = pathdf['latitude'][path_count-1]
        lon[count+1] = pathdf['longitude'][path_count-1]
        alt[count+1] = pathdf['altitude'][path_count-1]
        roll[count+1] = pathdf['roll'][path_count-1]
        pitch[count+1] = pathdf['pitch'][path_count-1]
        yaw[count+1] = pathdf['yaw'][path_count-1]
        tilt[count+1] = pathdf['tilt'][path_count-1]
        count += 1

# %%
max_ground_temp = np.flip(np.asarray(df['max_ground_temp(°C)']))
min_ground_temp = np.flip(np.asarray(df['min_ground_temp(°C)']))
max_air_temp = np.flip(np.asarray(df['max_air_temp(°C)']))
min_air_temp = np.flip(np.asarray(df['min_air_temp(°C)']))
mean_pressure = np.flip(np.asarray(df['mean_pressure(Pa)']))
UV_rad = np.flip(np.asarray(df['UV_Radiation']))

# %%
maindf = pd.DataFrame(data={'sol': rover_sols, 'latitude': lat, 'longitude': lon, 'altitude': alt, 'min_ground_temp': min_ground_temp, 'max_ground_temp': max_ground_temp, 'min_air_temp': min_air_temp, 'max_air_temp': max_air_temp, 'mean_pressure': mean_pressure, 'UV_Radiation': UV_rad, 'roll': roll, 'pitch': pitch, 'yaw': yaw, 'tilt': tilt})

# %%
maindf.to_csv('data/bigdf.csv')

# %%
smalldf = maindf
smalldf = smalldf.drop(['latitude', 'longitude', 'altitude', 'roll', 'pitch', 'yaw', 'tilt'], 1)

# %%
smalldf.to_csv('data/smalldf.csv')
